# %% [markdown]
# # SI 676 - Assignment 4: Metadata Extraction and Transformation Script

# %% [markdown]
# ## Collection List 1 - Libraries Collection

# %%
import csv
import json
import requests
from datetime import date

import glob
import os
from os.path import join

# %%
endpoint = 'https://www.loc.gov/free-to-use'
parameters = {
    'fo' : 'json'
}

# %%
collection = 'libraries'

# %%
collection_response = requests.get(endpoint + '/' + collection, params=parameters)

collection_json = collection_response.json()

# %%
item_url_list = []

for result in collection_json['content']['set']['items']:
    result_url = endpoint + result['link']
    item_url_list.append(result_url)

# %%
collection_set_list = os.path.join('libraries', 'collection_set_list-libraries.csv')
headers = ['image','link','title']

with open(collection_set_list, 'w', encoding='utf-8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=headers)
    writer.writeheader()
    for item in collection_json['content']['set']['items']:
        item['title'] = item['title'].rstrip()
        writer.writerow(item)
    print('wrote',collection_set_list)
# Out:
# wrote libraries/collection_set_list-libraries.csv

# %% [markdown]
# ## Collection Item Metadata 1 - Libraries Collection

# %%
endpoint = 'https://www.loc.gov'
parameters = {
    'fo' : 'json'
}

# %%
item_metadata_directory = os.path.join('libraries', 'libs_metadata')

if os.path.isdir(item_metadata_directory):
    print(item_metadata_directory,'exists')
else:
    os.mkdir(item_metadata_directory)
    print('created',item_metadata_directory)
# Out:
# created libraries/libs_metadata

# %%
item_count = 0
error_count = 0
file_count = 0

libraries_directory = 'libraries'
item_metadata_directory = 'libs_metadata'
item_metadata_file_start = 'item_metadata'
json_suffix = '.json'

with open(collection_set_list, 'r', encoding='utf-8', newline='') as f:
    reader = csv.DictReader(f, fieldnames=headers)
    for item in reader:
        if item['link'] == 'link':
            continue
        if '?' in item['link']:
            resource_ID = item['link']
            short_ID = item['link'].split('/')[2]
            item_metadata = requests.get(endpoint + resource_ID + '&fo=json')
            print('requested',item_metadata.url,item_metadata.status_code)
            if item_metadata.status_code != 200:
                print('requested',item_metadata.url,item_metadata.status_code)
                error_count += 1
                continue
            try:
                item_metadata.json()
            except: #basically this catches all of the highsmith photos with hhh in the ID
                error_count += 1
                print('no json found')
                continue
            fout = os.path.join(libraries_directory, item_metadata_directory, str(item_metadata_file_start + '-' + short_ID + json_suffix))
            with open(fout, 'w', encoding='utf-8') as json_file:
                json_file.write(json.dumps(item_metadata.json()['item']))
                file_count += 1
                print('wrote', fout)
            item_count += 1
        else:
            resource_ID = item['link']
            short_ID = item['link'].split('/')[2]
            item_metadata = requests.get(endpoint + resource_ID, params=parameters)
            print('requested',item_metadata.url,item_metadata.status_code)
            if item_metadata.status_code != 200:
                print('requested',item_metadata.url,item_metadata.status_code)
                error_count += 1
                continue
            try:
                item_metadata.json()
            except:
                error_count += 1
                print('no json found')
                continue
            fout = os.path.join(libraries_directory, item_metadata_directory, str(item_metadata_file_start + '-' + short_ID + json_suffix))
            with open(fout, 'w', encoding='utf-8') as json_file:
                json_file.write(json.dumps(item_metadata.json()['item']))
                file_count += 1
                print('wrote', fout)
            item_count += 1

print('--- mini LOG ---')
print('items requested:',item_count)
print('errors:',error_count)
print('files written:',file_count)
# Out:
# requested https://www.loc.gov/resource/cph.3f05183/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-cph.3f05183.json
# requested https://www.loc.gov/resource/highsm.20336/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.20336.json
# requested https://www.loc.gov/resource/fsa.8d24709/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-fsa.8d24709.json
# requested https://www.loc.gov/resource/highsm.36052/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.36052.json
# requested https://www.loc.gov/resource/highsm.51772/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.51772.json
# requested https://www.loc.gov/resource/cph.3b43255/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-cph.3b43255.json
# requested https://www.loc.gov/resource/highsm.20483/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.20483.json
# requested https://www.loc.gov/resource/highsm.29207/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.29207.json
# requested https://www.loc.gov/resource/fsa.8b32222/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-fsa.8b32222.json
# requested https://www.loc.gov/resource/highsm.64003/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.64003.json
# requested https://www.loc.gov/resource/ppmsca.15412/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ppmsca.15412.json
# requested https://www.loc.gov/resource/highsm.49335/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.49335.json
# requested https://www.loc.gov/resource/highsm.20497/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.20497.json
# requested https://www.loc.gov/resource/npcc.28724/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-npcc.28724.json
# requested https://www.loc.gov/resource/ds.06560/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ds.06560.json
# requested https://www.loc.gov/resource/hhh.hi0135.photos?fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.hi0135.photos.json
# requested https://www.loc.gov/resource/cph.3f05168/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-cph.3f05168.json
# requested https://www.loc.gov/resource/ppmsca.15375/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ppmsca.15375.json
# requested https://www.loc.gov/resource/highsm.53335/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.53335.json
# requested https://www.loc.gov/resource/hhh.ks0072.photos/?sp=2&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.ks0072.photos.json
# requested https://www.loc.gov/resource/highsm.34640/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.34640.json
# requested https://www.loc.gov/item/97517380/ 200
# no json found
# requested https://www.loc.gov/resource/ppmsca.18016/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ppmsca.18016.json
# requested https://www.loc.gov/resource/hhh.me0057.photos/?sp=1&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.me0057.photos.json
# requested https://www.loc.gov/resource/highsm.41101/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.41101.json
# requested https://www.loc.gov/resource/det.4a17925/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-det.4a17925.json
# requested https://www.loc.gov/resource/ppmsca.15426/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ppmsca.15426.json
# requested https://www.loc.gov/resource/ppmscd.00084/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ppmscd.00084.json
# requested https://www.loc.gov/resource/highsm.18384/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.18384.json
# requested https://www.loc.gov/resource/g3851e.ct006252/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-g3851e.ct006252.json
# requested https://www.loc.gov/resource/ppmsca.35590/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ppmsca.35590.json
# requested https://www.loc.gov/resource/hhh.il0998.sheet/?sp=1&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.il0998.sheet.json
# requested https://www.loc.gov/resource/hhh.ok0012.sheet/?sp=8&q=hhh.ok0012&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.ok0012.sheet.json
# requested https://www.loc.gov/resource/hhh.sc0767.photos/?sp=1&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.sc0767.photos.json
# requested https://www.loc.gov/resource/hhh.nj0089.photos/?sp=4&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.nj0089.photos.json
# requested https://www.loc.gov/resource/highsm.31350/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.31350.json
# requested https://www.loc.gov/resource/hhh.ri0071.photos/?sp=8&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.ri0071.photos.json
# requested https://www.loc.gov/resource/highsm.48241/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.48241.json
# requested https://www.loc.gov/resource/det.4a23603/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-det.4a23603.json
# requested https://www.loc.gov/resource/highsm.04362/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.04362.json
# requested https://www.loc.gov/resource/hhh.dc0121.photos/?sp=24&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.dc0121.photos.json
# requested https://www.loc.gov/resource/ppbd.00600/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ppbd.00600.json
# requested https://www.loc.gov/resource/fsa.8b14169/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-fsa.8b14169.json
# requested https://www.loc.gov/resource/highsm.32720/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.32720.json
# requested https://www.loc.gov/resource/fsa.8c22565/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-fsa.8c22565.json
# requested https://www.loc.gov/resource/mrg.00785/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-mrg.00785.json
# requested https://www.loc.gov/resource/hhh.ak0345.photos/?sp=2&fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.ak0345.photos.json
# requested https://www.loc.gov/resource/highsm.43863/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.43863.json
# requested https://www.loc.gov/resource/highsm.42123/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.42123.json
# requested https://www.loc.gov/resource/cph.3c18157/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-cph.3c18157.json
# requested https://www.loc.gov/resource/ds.06507/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-ds.06507.json
# requested https://www.loc.gov/resource/highsm.24333/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.24333.json
# requested https://www.loc.gov/resource/mrg.00788/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-mrg.00788.json
# requested https://www.loc.gov/resource/highsm.20216/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.20216.json
# requested https://www.loc.gov/resource/cph.3b41963/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-cph.3b41963.json
# requested https://www.loc.gov/resource/mrg.00432/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-mrg.00432.json
# requested https://www.loc.gov/item/93510022/ 200
# no json found
# requested https://www.loc.gov/resource/highsm.60215/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.60215.json
# requested https://www.loc.gov/item/2007684180/ 200
# no json found
# requested https://www.loc.gov/resource/highsm.50410/?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.50410.json
# requested https://www.loc.gov/resource/hhh.nv0134.photos?fo=json 200
# wrote libraries/libs_metadata/item_metadata-hhh.nv0134.photos.json
# requested https://www.loc.gov/resource/highsm.18402?fo=json 200
# wrote libraries/libs_metadata/item_metadata-highsm.18402.json
# --- mini LOG ---
# items requested: 59
# errors: 3
# files written: 59

# %% [markdown]
# ## Collection List 2 - Japanese Prints Collection

# %%
endpoint = 'https://www.loc.gov/free-to-use'
parameters = {
    'fo' : 'json'
}

# %%
collection = 'japanese-prints'

# %%
collection_response = requests.get(endpoint + '/' + collection, params=parameters)

collection_json = collection_response.json()

# %%
item_url_list = []

for result in collection_json['content']['set']['items']:
    result_url = endpoint + result['link']
    item_url_list.append(result_url)

# %%
collection_set_list = os.path.join('japanese_prints', 'collection_set_list-japanese.csv')
headers = ['image','link','title']

with open(collection_set_list, 'w', encoding='utf-8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=headers)
    writer.writeheader()
    for item in collection_json['content']['set']['items']:
        item['title'] = item['title'].rstrip()
        writer.writerow(item)
    print('wrote',collection_set_list)
# Out:
# wrote japanese_prints/collection_set_list-japanese.csv

# %% [markdown]
# ## Collection Item Metadata 2 - Japanese Prints Collection

# %%
endpoint = 'https://www.loc.gov'
parameters = {
    'fo' : 'json'
}

# %%
item_metadata_directory = os.path.join('japanese_prints', 'japanese_prints_metadata')

if os.path.isdir(item_metadata_directory):
    print(item_metadata_directory,'exists')
else:
    os.mkdir(item_metadata_directory)
    print('created',item_metadata_directory)
# Out:
# created japanese_prints/japanese_prints_metadata

# %%
item_count = 0
error_count = 0
file_count = 0

japanese_directory = 'japanese_prints'
item_metadata_directory = 'japanese_prints_metadata'
item_metadata_file_start = 'item_metadata'
json_suffix = '.json'

with open(collection_set_list, 'r', encoding='utf-8', newline='') as f:
    reader = csv.DictReader(f, fieldnames=headers)
    for item in reader:
        if item['link'] == 'link':
            continue
        if '?' in item['link']:
            resource_ID = item['link']
            short_ID = item['link'].split('/')[2]
            item_metadata = requests.get(endpoint + resource_ID + '&fo=json')
            print('requested',item_metadata.url,item_metadata.status_code)
            if item_metadata.status_code != 200:
                print('requested',item_metadata.url,item_metadata.status_code)
                error_count += 1
                continue
            try:
                item_metadata.json()
            except:
                error_count += 1
                print('no json found')
                continue
            fout = os.path.join(japanese_directory, item_metadata_directory, str(item_metadata_file_start + '-' + short_ID + json_suffix))
            with open(fout, 'w', encoding='utf-8') as json_file:
                json_file.write(json.dumps(item_metadata.json()['item']))
                file_count += 1
                print('wrote', fout)
            item_count += 1
        else:
            resource_ID = item['link']
            short_ID = item['link'].split('/')[2]
            item_metadata = requests.get(endpoint + resource_ID, params=parameters)
            print('requested',item_metadata.url,item_metadata.status_code)
            if item_metadata.status_code != 200:
                print('requested',item_metadata.url,item_metadata.status_code)
                error_count += 1
                continue
            try:
                item_metadata.json()
            except:
                error_count += 1
                print('no json found')
                continue
            fout = os.path.join(japanese_directory, item_metadata_directory, str(item_metadata_file_start + '-' + short_ID + json_suffix))
            with open(fout, 'w', encoding='utf-8') as json_file:
                json_file.write(json.dumps(item_metadata.json()['item']))
                file_count += 1
                print('wrote', fout)
            item_count += 1

print('--- mini LOG ---')
print('items requested:',item_count)
print('errors:',error_count)
print('files written:',file_count)
# Out:
# requested https://www.loc.gov/resource/jpd.01578/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01578.json
# requested https://www.loc.gov/resource/jpd.00154/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.00154.json
# requested https://www.loc.gov/resource/jpd.02457/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.02457.json
# requested https://www.loc.gov/resource/cph.3g10434/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10434.json
# requested https://www.loc.gov/resource/jpd.02608/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.02608.json
# requested https://www.loc.gov/resource/cph.3g10372/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10372.json
# requested https://www.loc.gov/resource/cph.3g10521/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10521.json
# requested https://www.loc.gov/resource/cph.3g08479/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-cph.3g08479.json
# requested https://www.loc.gov/resource/cph.3g10539/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10539.json
# requested https://www.loc.gov/resource/jpd.00046/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.00046.json
# requested https://www.loc.gov/resource/jpd.01307/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01307.json
# requested https://www.loc.gov/resource/jpd.00507/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.00507.json
# requested https://www.loc.gov/resource/jpd.01317/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01317.json
# requested https://www.loc.gov/resource/jpd.01581/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01581.json
# requested https://www.loc.gov/resource/jpd.00181/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.00181.json
# requested https://www.loc.gov/resource/jpd.00139/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.00139.json
# requested https://www.loc.gov/resource/jpd.01271/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01271.json
# requested https://www.loc.gov/resource/jpd.02467/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.02467.json
# requested https://www.loc.gov/resource/jpd.01822/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01822.json
# requested https://www.loc.gov/resource/jpd.01803/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01803.json
# requested https://www.loc.gov/resource/jpd.00790/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.00790.json
# requested https://www.loc.gov/resource/jpd.00278/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.00278.json
# requested https://www.loc.gov/resource/jpd.02925/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.02925.json
# requested https://www.loc.gov/resource/jpd.01197/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01197.json
# requested https://www.loc.gov/resource/jpd.02148/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.02148.json
# requested https://www.loc.gov/resource/jpd.01328/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01328.json
# requested https://www.loc.gov/resource/jpd.00501/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.00501.json
# requested https://www.loc.gov/resource/jpd.02015/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.02015.json
# requested https://www.loc.gov/resource/jpd.01361/?fo=json 200
# wrote japanese_prints/japanese_prints_metadata/item_metadata-jpd.01361.json
# --- mini LOG ---
# items requested: 29
# errors: 0
# files written: 29

# %% [markdown]
# ## Item Metadata Transformation 1 - Libraries Collection

# %%
file_count = 0

for file in glob.glob('libraries/libs_metadata/item_metadata-*.json'):
    file_count += 1
    print(file)
    
print('found',file_count)
# Out:
# libraries/libs_metadata/item_metadata-cph.3c18157.json
# libraries/libs_metadata/item_metadata-ppbd.00600.json
# libraries/libs_metadata/item_metadata-mrg.00785.json
# libraries/libs_metadata/item_metadata-cph.3f05183.json
# libraries/libs_metadata/item_metadata-g3851e.ct006252.json
# libraries/libs_metadata/item_metadata-highsm.43863.json
# libraries/libs_metadata/item_metadata-ppmsca.18016.json
# libraries/libs_metadata/item_metadata-highsm.20497.json
# libraries/libs_metadata/item_metadata-fsa.8b14169.json
# libraries/libs_metadata/item_metadata-ppmsca.35590.json
# libraries/libs_metadata/item_metadata-mrg.00788.json
# libraries/libs_metadata/item_metadata-highsm.34640.json
# libraries/libs_metadata/item_metadata-highsm.20336.json
# libraries/libs_metadata/item_metadata-fsa.8c22565.json
# libraries/libs_metadata/item_metadata-cph.3b41963.json
# libraries/libs_metadata/item_metadata-ppmsca.15412.json
# libraries/libs_metadata/item_metadata-highsm.32720.json
# libraries/libs_metadata/item_metadata-mrg.00432.json
# libraries/libs_metadata/item_metadata-hhh.hi0135.photos.json
# libraries/libs_metadata/item_metadata-hhh.il0998.sheet.json
# libraries/libs_metadata/item_metadata-det.4a17925.json
# libraries/libs_metadata/item_metadata-highsm.24333.json
# libraries/libs_metadata/item_metadata-ppmscd.00084.json
# libraries/libs_metadata/item_metadata-hhh.ks0072.photos.json
# libraries/libs_metadata/item_metadata-highsm.64003.json
# libraries/libs_metadata/item_metadata-highsm.41101.json
# libraries/libs_metadata/item_metadata-highsm.31350.json
# libraries/libs_metadata/item_metadata-hhh.ok0012.sheet.json
# libraries/libs_metadata/item_metadata-hhh.sc0767.photos.json
# libraries/libs_metadata/item_metadata-hhh.ri0071.photos.json
# libraries/libs_metadata/item_metadata-cph.3b43255.json
# libraries/libs_metadata/item_metadata-hhh.me0057.photos.json
# libraries/libs_metadata/item_metadata-highsm.36052.json
# libraries/libs_metadata/item_metadata-highsm.60215.json
# libraries/libs_metadata/item_metadata-cph.3f05168.json
# libraries/libs_metadata/item_metadata-ds.06507.json
# libraries/libs_metadata/item_metadata-highsm.51772.json
# libraries/libs_metadata/item_metadata-highsm.18402.json
# libraries/libs_metadata/item_metadata-ppmsca.15375.json
# libraries/libs_metadata/item_metadata-hhh.nv0134.photos.json
# libraries/libs_metadata/item_metadata-highsm.20216.json
# libraries/libs_metadata/item_metadata-highsm.49335.json
# libraries/libs_metadata/item_metadata-highsm.04362.json
# libraries/libs_metadata/item_metadata-npcc.28724.json
# libraries/libs_metadata/item_metadata-highsm.29207.json
# libraries/libs_metadata/item_metadata-det.4a23603.json
# libraries/libs_metadata/item_metadata-ds.06560.json
# libraries/libs_metadata/item_metadata-hhh.ak0345.photos.json
# libraries/libs_metadata/item_metadata-hhh.nj0089.photos.json
# libraries/libs_metadata/item_metadata-highsm.20483.json
# libraries/libs_metadata/item_metadata-highsm.50410.json
# libraries/libs_metadata/item_metadata-fsa.8b32222.json
# libraries/libs_metadata/item_metadata-highsm.18384.json
# libraries/libs_metadata/item_metadata-ppmsca.15426.json
# libraries/libs_metadata/item_metadata-highsm.48241.json
# libraries/libs_metadata/item_metadata-fsa.8d24709.json
# libraries/libs_metadata/item_metadata-highsm.53335.json
# libraries/libs_metadata/item_metadata-highsm.42123.json
# libraries/libs_metadata/item_metadata-hhh.dc0121.photos.json
# found 59

# %%
list_of_item_metadata_files = list() 
for file in glob.glob('libraries/libs_metadata/item_metadata-*.json'):
    list_of_item_metadata_files.append(file)

# %%
list_of_item_metadata_files.sort()

for file in list_of_item_metadata_files:
    print(file)
# Out:
# libraries/libs_metadata/item_metadata-cph.3b41963.json
# libraries/libs_metadata/item_metadata-cph.3b43255.json
# libraries/libs_metadata/item_metadata-cph.3c18157.json
# libraries/libs_metadata/item_metadata-cph.3f05168.json
# libraries/libs_metadata/item_metadata-cph.3f05183.json
# libraries/libs_metadata/item_metadata-det.4a17925.json
# libraries/libs_metadata/item_metadata-det.4a23603.json
# libraries/libs_metadata/item_metadata-ds.06507.json
# libraries/libs_metadata/item_metadata-ds.06560.json
# libraries/libs_metadata/item_metadata-fsa.8b14169.json
# libraries/libs_metadata/item_metadata-fsa.8b32222.json
# libraries/libs_metadata/item_metadata-fsa.8c22565.json
# libraries/libs_metadata/item_metadata-fsa.8d24709.json
# libraries/libs_metadata/item_metadata-g3851e.ct006252.json
# libraries/libs_metadata/item_metadata-hhh.ak0345.photos.json
# libraries/libs_metadata/item_metadata-hhh.dc0121.photos.json
# libraries/libs_metadata/item_metadata-hhh.hi0135.photos.json
# libraries/libs_metadata/item_metadata-hhh.il0998.sheet.json
# libraries/libs_metadata/item_metadata-hhh.ks0072.photos.json
# libraries/libs_metadata/item_metadata-hhh.me0057.photos.json
# libraries/libs_metadata/item_metadata-hhh.nj0089.photos.json
# libraries/libs_metadata/item_metadata-hhh.nv0134.photos.json
# libraries/libs_metadata/item_metadata-hhh.ok0012.sheet.json
# libraries/libs_metadata/item_metadata-hhh.ri0071.photos.json
# libraries/libs_metadata/item_metadata-hhh.sc0767.photos.json
# libraries/libs_metadata/item_metadata-highsm.04362.json
# libraries/libs_metadata/item_metadata-highsm.18384.json
# libraries/libs_metadata/item_metadata-highsm.18402.json
# libraries/libs_metadata/item_metadata-highsm.20216.json
# libraries/libs_metadata/item_metadata-highsm.20336.json
# libraries/libs_metadata/item_metadata-highsm.20483.json
# libraries/libs_metadata/item_metadata-highsm.20497.json
# libraries/libs_metadata/item_metadata-highsm.24333.json
# libraries/libs_metadata/item_metadata-highsm.29207.json
# libraries/libs_metadata/item_metadata-highsm.31350.json
# libraries/libs_metadata/item_metadata-highsm.32720.json
# libraries/libs_metadata/item_metadata-highsm.34640.json
# libraries/libs_metadata/item_metadata-highsm.36052.json
# libraries/libs_metadata/item_metadata-highsm.41101.json
# libraries/libs_metadata/item_metadata-highsm.42123.json
# libraries/libs_metadata/item_metadata-highsm.43863.json
# libraries/libs_metadata/item_metadata-highsm.48241.json
# libraries/libs_metadata/item_metadata-highsm.49335.json
# libraries/libs_metadata/item_metadata-highsm.50410.json
# libraries/libs_metadata/item_metadata-highsm.51772.json
# libraries/libs_metadata/item_metadata-highsm.53335.json
# libraries/libs_metadata/item_metadata-highsm.60215.json
# libraries/libs_metadata/item_metadata-highsm.64003.json
# libraries/libs_metadata/item_metadata-mrg.00432.json
# libraries/libs_metadata/item_metadata-mrg.00785.json
# libraries/libs_metadata/item_metadata-mrg.00788.json
# libraries/libs_metadata/item_metadata-npcc.28724.json
# libraries/libs_metadata/item_metadata-ppbd.00600.json
# libraries/libs_metadata/item_metadata-ppmsca.15375.json
# libraries/libs_metadata/item_metadata-ppmsca.15412.json
# libraries/libs_metadata/item_metadata-ppmsca.15426.json
# libraries/libs_metadata/item_metadata-ppmsca.18016.json
# libraries/libs_metadata/item_metadata-ppmsca.35590.json
# libraries/libs_metadata/item_metadata-ppmscd.00084.json

# %%
with open(list_of_item_metadata_files[0], 'r', encoding='utf-8') as item:
    print('file:',list_of_item_metadata_files[0],'\n')
    item_data = json.load(item)
    for element in item_data.keys():
        print(element,':',item_data[element])
# Out:
# file: libraries/libs_metadata/item_metadata-cph.3b41963.json
#
# _version_ : 1731714874606616576
# access_restricted : False
# aka : ['https://www.loc.gov/pictures/item/91787443/', 'http://www.loc.gov/item/91787443/', 'http://www.loc.gov/pictures/item/91787443/', 'https://www.loc.gov/pictures/collection/cph/item/91787443/', 'http://www.loc.gov/pictures/collection/cph/item/91787443/', 'http://www.loc.gov/resource/cph.3b41963/', 'http://lccn.loc.gov/91787443', 'https://hdl.loc.gov/loc.pnp/cph.3b41963']
# call_number : SSF - Libraries--Georgia--Cordele <item> [P&P]
# campaigns : []
# control_number :
# created : 2016-04-21T09:17:00Z
# created_published : ['[ca. 1916]']
# created_published_date : [ca. 1916]
# date : 1916-01-01
# dates : [{'1916': 'https://www.loc.gov/search/?dates=1916/1916&fo=json'}]
# description : ['1 photographic print. | Photo shows a group of children posed on and in front of steps, roof and dome draped with stars and stripes banners. A Carnegie grant for $10,000 in 1903 funded this building, with an  additional $7,556 in 1916 for remodeling. Still used as a public library.']
# digital_id : ['cph 3b41963 //hdl.loc.gov/loc.pnp/cph.3b41963']
# digitized : True
# display_offsite : True
# extract_timestamp : 2021-08-25T14:59:01.036Z
# extract_urls : ['http://www.loc.gov/pictures/collection/cph/item/91787443/#cph', 'http://lccn.loc.gov/91787443#catalog-split-11']
# format : [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}]
# format_headings : ['Photographic prints--1910-1920.']
# genre : ['Photographic prints--1910-1920']
# group : ['cph', 'catalog-split-11', 'catalog', 'miscellaneous-items-high-demand', 'main-catalog-split-11', 'main-catalog']
# hassegments : False
# id : http://www.loc.gov/item/91787443/
# image_url : ['https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963_150px.jpg#h=121&w=150', 'https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963t.gif#h=121&w=150', 'https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963r.jpg#h=515&w=640', 'https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963v.jpg#h=823&w=1024']
# index : 1
# item : {'call_number': 'SSF - Libraries--Georgia--Cordele <item> [P&P]', 'control_number': '91787443', 'created': '2016-04-21T09:17:00Z', 'created_published': '[ca. 1916]', 'created_published_date': '[ca. 1916]', 'date': '[ca. 1916]', 'digital_id': ['cph 3b41963 //hdl.loc.gov/loc.pnp/cph.3b41963'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Photographic%20prints--1910-1920.&co=cph', 'title': 'Photographic prints--1910-1920.'}], 'genre': ['Photographic prints--1910-1920'], 'id': '91787443', 'link': 'https://www.loc.gov/pictures/item/91787443/', 'location': ['Georgia--Cordele'], 'marc': 'https://www.loc.gov/pictures/item/91787443/marc/', 'medium': ['1 photographic print.'], 'medium_brief': '1 photographic print.', 'mediums': ['1 photographic print.'], 'modified': '2016-04-21T09:17:00Z', 'notes': ['At bottom right of photo: "Cordele Book Co."', 'Wittemann Collection.'], 'number_former_id': ['https://www.loc.gov/item/91787443', 'https://www.loc.gov/item/11583075'], 'other_control_numbers': ['11583075'], 'place': [{'latitude': '', 'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Georgia--Cordele&co=cph', 'longitude': '', 'title': 'Georgia--Cordele'}], 'reproduction_number': 'LC-USZ62-95830 (b&w film copy neg.)', 'resource_links': ['//hdl.loc.gov/loc.pnp/cph.3b41963'], 'rights_advisory': 'No known restrictions on publication.', 'rights_information': 'No known restrictions on publication.', 'service_low': 'https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963_150px.jpg', 'service_medium': 'https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963r.jpg', 'sort_date': '1916', 'source_created': '1991-08-22T00:00:00Z', 'source_modified': '2012-06-14T21:04:56Z', 'subject_headings': ['Libraries--Georgia--Cordele--1910-1920.', 'Georgia--Cordele'], 'subjects': ['Libraries--Georgia--Cordele--1910-1920'], 'summary': 'Photo shows a group of children posed on and in front of steps, roof and dome draped with stars and stripes banners. A Carnegie grant for $10,000 in 1903 funded this building, with an  additional $7,556 in 1916 for remodeling. Still used as a public library.', 'thumb_gallery': 'https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963_150px.jpg', 'title': 'Carnegie Library, Cordele, Georgia'}
# language : ['english']
# languages : [{'english': 'https://www.loc.gov/search/?fa=language:english&fo=json'}]
# library_of_congress_control_number : 91787443
# link : https://www.loc.gov/pictures/item/91787443/
# location : ['georgia', 'cordele']
# locations : [{'cordele': 'https://www.loc.gov/search/?fa=location:cordele&fo=json'}, {'georgia': 'https://www.loc.gov/search/?fa=location:georgia&fo=json'}]
# marc : https://www.loc.gov/pictures/item/91787443/marc/
# medium : ['1 photographic print.']
# medium_brief : 1 photographic print.
# mime_type : ['image/gif', 'image/jpg', 'image/tif']
# modified : 2016-04-21T09:17:00Z
# notes : ['At bottom right of photo: "Cordele Book Co."', 'Wittemann Collection.']
# number : ['91787443', 'http://www.loc.gov/item/11583075', 'http://www.loc.gov/item/91787443', '2012-06-14t21:04:56']
# number_former_id : ['http://www.loc.gov/item/11583075', 'http://www.loc.gov/item/91787443']
# number_lccn : ['91787443']
# number_source_modified : ['2012-06-14t21:04:56']
# online_format : ['image']
# original_format : ['photo, print, drawing']
# other_control_numbers : ['11583075']
# other_formats : [{'label': 'MARCXML Record', 'link': 'https://lccn.loc.gov/91787443/marcxml'}, {'label': 'MODS Record', 'link': 'https://lccn.loc.gov/91787443/mods'}, {'label': 'Dublin Core Record', 'link': 'https://lccn.loc.gov/91787443/dc'}]
# other_title : []
# partof : [{'count': 121394, 'title': 'miscellaneous items in high demand', 'url': 'https://www.loc.gov/search/?fa=partof:miscellaneous+items+in+high+demand&fo=json'}, {'count': 988095, 'title': 'prints & photographs online catalog (library of congress)', 'url': 'https://www.loc.gov/search/?fa=partof:prints+%26+photographs+online+catalog+%28library+of+congress%29&fo=json'}, {'count': 1049052, 'title': 'prints and photographs division', 'url': 'https://www.loc.gov/search/?fa=partof:prints+and+photographs+division&fo=json'}, {'count': 1487378, 'title': 'catalog', 'url': 'https://www.loc.gov/search/?fa=partof:catalog&fo=json'}]
# place : [{'latitude': '', 'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Georgia--Cordele&co=cph', 'longitude': '', 'title': 'Georgia--Cordele'}]
# related : {'neighbors': 'https://www.loc.gov/pictures/related/?&co=cph&pk=91787443&st=gallery&sb=call_number#focus'}
# reproduction_number : LC-USZ62-95830 (b&w film copy neg.)
# reproductions : []
# resource_links : ['//hdl.loc.gov/loc.pnp/cph.3b41963']
# resources : [{'caption': 'digital file from b&w film copy neg.', 'files': 1, 'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963_150px.jpg', 'url': 'https://www.loc.gov/resource/cph.3b41963/'}]
# rights : []
# rights_advisory : No known restrictions on publication.
# rights_information : No known restrictions on publication.
# score : 19.42971
# shard : 00
# shelf_id : SSF - Libraries--Georgia--Cordele <item> [P&P]
# site : ['pictures', 'catalog']
# sort_date : 1916
# source_created : 1991-08-22T00:00:00Z
# source_modified : 2012-06-14T21:04:56Z
# subject : ['libraries', 'georgia', 'photographic prints', 'cordele']
# subject_headings : ['Libraries--Georgia--Cordele--1910-1920']
# subjects : [{'cordele': 'https://www.loc.gov/search/?fa=subject:cordele&fo=json'}, {'georgia': 'https://www.loc.gov/search/?fa=subject:georgia&fo=json'}, {'libraries': 'https://www.loc.gov/search/?fa=subject:libraries&fo=json'}, {'photographic prints': 'https://www.loc.gov/search/?fa=subject:photographic+prints&fo=json'}]
# summary : Photo shows a group of children posed on and in front of steps, roof and dome draped with stars and stripes banners. A Carnegie grant for $10,000 in 1903 funded this building, with an  additional $7,556 in 1916 for remodeling. Still used as a public library.
# thumb_gallery : https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963_150px.jpg
# timestamp : 2022-05-02T11:46:38.938Z
# title : Carnegie Library, Cordele, Georgia
# type : ['photo, print, drawing']
# unrestricted : True
# url : https://www.loc.gov/item/91787443/

# %%
item_data['item']['title']
# Out:
# 'Carnegie Library, Cordele, Georgia'

# %%
collection_info_csv = 'collection_items_data-libraries.csv'

date_string_for_today = date.today().strftime('%Y-%m-%d')

headers = ['item_type', 'date_extracted', 'source_file', 'image_url', 'creator', 'date', 'dig_format', 'phys_format', 'language', 'lc_call', 'lc_control', 'link', 'notes', 'rights', 'subject', 'summary', 'title']

# %%
file_count = 0
items_written = 0
error_count = 0

for file in list_of_item_metadata_files:
    file_count += 1
    with open(file, 'r', encoding='utf-8') as data:
        try:
            item = json.load(data)
        except:
            print('error loading',file)
            error_count += 1
            continue

        item_type = 'Item'

        date_extracted = date_string_for_today

        source_file = str(file)

        image_url = item['image_url'][-1]

        try:
            creator = item['item']['creators'][0]['title']
        except:
            creator = 'Anonymous'

        try:
            date = item['item']['date']
        except:
            date = 'Unknown'

        try:
            dig_format = item['item']['format'][0]
        except:
            dig_format = 'Not Found'

        try:
            phys_format = item['item']['formats'][0]['title']
        except:
            phys_format = 'Not Found'

        try:
            language = item['language'][0]
        except:
            language = 'Not Found'

        try:
            lc_call = item['call_number']
        except:
            lc_call = 'Unknown'

        try:
            lc_control = item['item']['control_number']
        except:
            lc_control = 'Unknown'

        try:
            link = item['link']
        except:
            link = 'Not Found'

        try:
            notes = '; '.join(item['notes'])
        except:
            notes = 'None'

        try:
            rights = item['rights_information']
        except:
            rights = 'Unknown'

        try:
            subject = item['item']['subject_headings']
        except:
            subject = 'None'

        try:
            summary = item['summary']
        except:
            summary = 'Not Found'

        title = item['title']

        row_dict = dict()
        row_dict['item_type'] = item_type
        row_dict['date_extracted'] = date_extracted
        row_dict['source_file'] = source_file
        row_dict['image_url'] = image_url
        row_dict['creator'] = creator
        row_dict['date'] = date
        row_dict['dig_format'] = dig_format
        row_dict['phys_format'] = phys_format
        row_dict['language'] = language
        row_dict['lc_call'] = lc_call
        row_dict['lc_control'] = lc_control
        row_dict['link'] = link
        row_dict['notes'] = notes
        row_dict['rights'] = rights
        row_dict['subject'] = subject
        row_dict['summary'] = summary
        row_dict['title'] = title


        with open(collection_info_csv, 'a', encoding='utf-8') as fout:
            writer = csv.DictWriter(fout, fieldnames=headers)
            if items_written == 0:
                writer.writeheader()
            writer.writerow(row_dict)
            items_written += 1
            print(f'adding item {items_written}')

print('\n\n--- LOG ---')
print('wrote',collection_info_csv)
print('with',items_written,'items')
print(error_count,'errors (info not written)')
# Out:
# adding item 1
# adding item 2
# adding item 3
# adding item 4
# adding item 5
# adding item 6
# adding item 7
# adding item 8
# adding item 9
# adding item 10
# adding item 11
# adding item 12
# adding item 13
# adding item 14
# adding item 15
# adding item 16
# adding item 17
# adding item 18
# adding item 19
# adding item 20
# adding item 21
# adding item 22
# adding item 23
# adding item 24
# adding item 25
# adding item 26
# adding item 27
# adding item 28
# adding item 29
# adding item 30
# adding item 31
# adding item 32
# adding item 33
# adding item 34
# adding item 35
# adding item 36
# adding item 37
# adding item 38
# adding item 39
# adding item 40
# adding item 41
# adding item 42
# adding item 43
# adding item 44
# adding item 45
# adding item 46
# adding item 47
# adding item 48
# adding item 49
# adding item 50
# adding item 51
# adding item 52
# adding item 53
# adding item 54
# adding item 55
# adding item 56
# adding item 57
# adding item 58
# adding item 59
#
#
# --- LOG ---
# wrote collection_items_data-libraries.csv
# with 59 items
# 0 errors (info not written)

# %% [markdown]
# ## Item Metadata Transformation 2 - Japanese Prints Collection

# %%
file_count = 0

for file in glob.glob('japanese_prints/japanese_prints_metadata/item_metadata-*.json'):
    file_count += 1
    print(file)
    
print('found',file_count)
# Out:
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01361.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10372.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01822.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10539.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02015.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00507.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01317.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01803.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02608.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00501.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00278.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01307.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01328.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02457.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g08479.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10434.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02925.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01581.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01578.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02467.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01271.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10521.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02148.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01197.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00790.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00181.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00139.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00046.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00154.json
# found 29

# %%
list_of_item_metadata_files = list() 
for file in glob.glob('japanese_prints/japanese_prints_metadata/item_metadata-*.json'):
    list_of_item_metadata_files.append(file)

# %%
list_of_item_metadata_files.sort()

for file in list_of_item_metadata_files:
    print(file)
# Out:
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g08479.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10372.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10434.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10521.json
# japanese_prints/japanese_prints_metadata/item_metadata-cph.3g10539.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00046.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00139.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00154.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00181.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00278.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00501.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00507.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.00790.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01197.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01271.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01307.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01317.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01328.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01361.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01578.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01581.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01803.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.01822.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02015.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02148.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02457.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02467.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02608.json
# japanese_prints/japanese_prints_metadata/item_metadata-jpd.02925.json

# %%
with open(list_of_item_metadata_files[0], 'r', encoding='utf-8') as item:
    print('file:',list_of_item_metadata_files[0],'\n')
    item_data = json.load(item)
    for element in item_data.keys():
        print(element,':',item_data[element])
# Out:
# file: japanese_prints/japanese_prints_metadata/item_metadata-cph.3g08479.json
#
# _version_ : 1731410668559532032
# access_restricted : False
# aka : ['https://www.loc.gov/pictures/item/2002700239/', 'http://www.loc.gov/item/2002700239/', 'http://www.loc.gov/pictures/item/2002700239/', 'https://www.loc.gov/pictures/collection/jpd/item/2002700239/', 'http://www.loc.gov/pictures/collection/jpd/item/2002700239/', 'http://www.loc.gov/resource/cph.3g08479/', 'http://www.loc.gov/resource/cph.3g08480/', 'http://www.loc.gov/resource/cph.3g08481/', 'http://www.loc.gov/resource/cph.3a24782/', 'http://www.loc.gov/resource/cph.3a24783/', 'http://www.loc.gov/resource/cph.3a24784/', 'https://hdl.loc.gov/loc.pnp/cph.3g08481', 'https://hdl.loc.gov/loc.pnp/cph.3g08480', 'https://hdl.loc.gov/loc.pnp/cph.3a24783', 'https://hdl.loc.gov/loc.pnp/cph.3a24782', 'https://hdl.loc.gov/loc.pnp/cph.3g08479', 'http://lccn.loc.gov/2002700239', 'https://hdl.loc.gov/loc.pnp/cph.3a24784']
# call_number : FP 2 - Chadbourne, no. 101 a, b, c (D size) [P&P]
# campaigns : []
# contributor_names : ['Ochiai, Yoshiiku, 1833-1904, artist']
# contributors : [{'ochiai, yoshiiku': 'https://www.loc.gov/search/?fa=contributor:ochiai,+yoshiiku&fo=json'}]
# control_number :
# created : 2021-08-06T12:42:38Z
# created_published : ['Japan : Kiya, 1860.']
# created_published_date : 1860.
# date : 1860-01-01
# dates : [{'1860': 'https://www.loc.gov/search/?dates=1860/1860&fo=json'}]
# description : ['1 print on hōsho paper (3 sheets) : woodcut, color ; 36.5 x 24.5 cm. (each block), 37 x 24.8 cm. (each sheet) | Japanese triptych print shows visitors from several nations enjoying a party in the Fan Room of the Gankirō.']
# digital_id : ['cph 3g08479 //hdl.loc.gov/loc.pnp/cph.3g08479', 'cph 3g08480 //hdl.loc.gov/loc.pnp/cph.3g08480', 'cph 3g08481 //hdl.loc.gov/loc.pnp/cph.3g08481', 'cph 3a24782 //hdl.loc.gov/loc.pnp/cph.3a24782', 'cph 3a24783 //hdl.loc.gov/loc.pnp/cph.3a24783', 'cph 3a24784 //hdl.loc.gov/loc.pnp/cph.3a24784']
# digitized : True
# display_offsite : True
# extract_timestamp : 2021-09-01T22:52:49.495Z
# extract_urls : ['http://www.loc.gov/pictures/collection/jpd/item/2002700239/#jpd', 'http://lccn.loc.gov/2002700239#catalog-split-09']
# format : [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}]
# format_headings : ['Triptychs--Japanese--1860.', 'Woodcuts--Japanese--Color--1860.']
# genre : ['Triptychs--Japanese--1860', 'Woodcuts--Japanese--Color--1860']
# group : ['jpd', 'catalog-split-09', 'catalog', 'japanese-fine-prints-pre-1915', 'main-catalog-split-09', 'main-catalog']
# hassegments : False
# id : http://www.loc.gov/item/2002700239/
# image_url : ['https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g08000/3g08400/3g08479_150px.jpg#h=150&w=119', 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g08000/3g08400/3g08479t.gif#h=150&w=119', 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g08000/3g08400/3g08479r.jpg#h=640&w=508', 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g08000/3g08400/3g08479v.jpg#h=1024&w=813']
# index : 1
# item : {'call_number': 'FP 2 - Chadbourne, no. 101 a, b, c (D size) [P&P]', 'contributors': ['Ochiai, Yoshiiku, 1833-1904, artist.'], 'control_number': '2002700239', 'created': '2021-08-06T12:42:38Z', 'created_published': 'Japan : Kiya, 1860.', 'created_published_date': '1860.', 'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Ochiai%2C%20Yoshiiku%2C%201833-1904&co=jpd', 'role': 'artist', 'title': 'Ochiai, Yoshiiku, 1833-1904'}], 'date': '1860.', 'digital_id': ['cph 3g08479 //hdl.loc.gov/loc.pnp/cph.3g08479', 'cph 3g08480 //hdl.loc.gov/loc.pnp/cph.3g08480', 'cph 3g08481 //hdl.loc.gov/loc.pnp/cph.3g08481', 'cph 3a24782 //hdl.loc.gov/loc.pnp/cph.3a24782', 'cph 3a24783 //hdl.loc.gov/loc.pnp/cph.3a24783', 'cph 3a24784 //hdl.loc.gov/loc.pnp/cph.3a24784'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Triptychs--Japanese--1860.&co=jpd', 'title': 'Triptychs--Japanese--1860.'}, {'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Woodcuts--Japanese--Color--1860.&co=jpd', 'title': 'Woodcuts--Japanese--Color--1860.'}], 'genre': ['Triptychs--Japanese--1860', 'Woodcuts--Japanese--Color--1860'], 'id': '2002700239', 'language': ['jpn'], 'link': 'https://www.loc.gov/pictures/item/2002700239/', 'location': ['Japan--Yokohama-shi'], 'marc': 'https://www.loc.gov/pictures/item/2002700239/marc/', 'medium': ['1 print on hōsho paper (3 sheets) : woodcut, color ; 36.5 x 24.5 cm. (each block), 37 x 24.8 cm. (each sheet)'], 'medium_brief': '1 print on hōsho paper (3 sheets) :', 'mediums': ['1 print on hōsho paper (3 sheets) : woodcut, color ; 36.5 x 24.5 cm. (each block), 37 x 24.8 cm. (each sheet)'], 'modified': '2021-08-06T12:42:49Z', 'notes': ['Caption label from exhibit "Floating World," Japan and the West, Artistic Cross-Fertilization section: A Drinking Party. This triptych depicts foreigners drinking at the Gankirô Tea House, a famous pleasure-seeking place for foreign merchants in Yokohama. People from the five treaty nations England, France, Russia, Holland, and the United States were popular subject matter for Yokohama artists. The five countries were often expanded to six to include China (here refered to as Nanking), a longtime trade partner with Japan. The artist of this print, Ochiai Yoshiiku (1833-1904), was the son of a tea house proprietor in Asakusa.', 'Title from item.', 'Signature: Ikkeisai Yoshiiku ga.', 'Engraving attributed to: Hori Take.', 'Seal date: Monkey 12.', 'Triptych in 3 sections (matted together): right (101a), center (101b), left (101c).', 'Annotations, stamps, etc. on verso of print: 75; 47623a (white label).', 'Yokohama : prints from nineteenth-century Japan / Ann Yonemura. Washington, D.C. : Arthur M. Sackler Gallery : Smithsonian Institution Press, c1990, no. 59 (p. 149)', 'The Floating world of Ukiyo-e: shadows, dreams and substance / essays by Sandy Kita ... [et al.]. New York: Harry N. Abrams, in association with the Library of Congress, 2001, no. 106, p. 171', 'Earlier control number: 9942.1-7.', 'Gift; Mrs. E. Crane Chadbourne; 1930; (DLC/PP-1930:47623a).', 'Forms part of: Chadbourne collection of Japanese prints (Library of Congress).', 'Exhibited: "The Floating world of Ukiyo-e: shadows, dreams and substances," organized by the Library of Congress, 2001.', 'Exhibited: "Steeped in History : The Art of Tea" at the Fowler Museum, University of California, Los Angeles, 2009.'], 'number_former_id': ['https://www.loc.gov/item/2002700239', 'https://www.loc.gov/item/cha2001000128/PP', 'https://www.loc.gov/item/12963981'], 'other_control_numbers': ['12963981', 'cha2001000128/PP'], 'other_title': ['Five nations - merrymaking at the Gankirō tea house.'], 'part_of': 'Chadbourne collection of Japanese prints (Library of Congress)', 'place': [{'latitude': '', 'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Japan--Yokohama-shi&co=jpd', 'longitude': '', 'title': 'Japan--Yokohama-shi'}], 'repository': 'Librar ...
# language : ['japanese', 'english']
# languages : [{'english': 'https://www.loc.gov/search/?fa=language:english&fo=json'}, {'japanese': 'https://www.loc.gov/search/?fa=language:japanese&fo=json'}]
# library_of_congress_control_number : 2002700239
# link : https://www.loc.gov/pictures/item/2002700239/
# location : ['japan', 'yokohama']
# locations : [{'japan': 'https://www.loc.gov/search/?fa=location:japan&fo=json'}, {'yokohama': 'https://www.loc.gov/search/?fa=location:yokohama&fo=json'}]
# marc : https://www.loc.gov/pictures/item/2002700239/marc/
# medium : ['1 print on hōsho paper (3 sheets) : woodcut, color ; 36.5 x 24.5 cm. (each block), 37 x 24.8 cm. (each sheet)']
# medium_brief : 1 print on hōsho paper (3 sheets) :
# mime_type : ['image/gif', 'image/jpg', 'image/tif']
# modified : 2021-08-06T12:42:49Z
# notes : ['Caption label from exhibit "Floating World," Japan and the West, Artistic Cross-Fertilization section: A Drinking Party. This triptych depicts foreigners drinking at the Gankirô Tea House, a famous pleasure-seeking place for foreign merchants in Yokohama. People from the five treaty nations England, France, Russia, Holland, and the United States were popular subject matter for Yokohama artists. The five countries were often expanded to six to include China (here refered to as Nanking), a longtime trade partner with Japan. The artist of this print, Ochiai Yoshiiku (1833-1904), was the son of a tea house proprietor in Asakusa.', 'Title from item.', 'Signature: Ikkeisai Yoshiiku ga.', 'Engraving attributed to: Hori Take.', 'Seal date: Monkey 12.', 'Triptych in 3 sections (matted together): right (101a), center (101b), left (101c).', 'Annotations, stamps, etc. on verso of print: 75; 47623a (white label).', 'Yokohama : prints from nineteenth-century Japan / Ann Yonemura. Washington, D.C. : Arthur M. Sackler Gallery : Smithsonian Institution Press, c1990, no. 59 (p. 149)', 'The Floating world of Ukiyo-e: shadows, dreams and substance / essays by Sandy Kita ... [et al.]. New York: Harry N. Abrams, in association with the Library of Congress, 2001, no. 106, p. 171', 'Earlier control number: 9942.1-7.', 'Gift; Mrs. E. Crane Chadbourne; 1930; (DLC/PP-1930:47623a).', 'Forms part of: Chadbourne collection of Japanese prints (Library of Congress).', 'Exhibited: "The Floating world of Ukiyo-e: shadows, dreams and substances," organized by the Library of Congress, 2001.', 'Exhibited: "Steeped in History : The Art of Tea" at the Fowler Museum, University of California, Los Angeles, 2009.']
# number : ['2020-12-28t18:44:03', 'http://www.loc.gov/item/cha2001000128/pp', '2002700239', 'http://www.loc.gov/item/2002700239', 'http://www.loc.gov/item/12963981']
# number_former_id : ['http://www.loc.gov/item/12963981', 'http://www.loc.gov/item/cha2001000128/pp', 'http://www.loc.gov/item/2002700239']
# number_lccn : ['2002700239']
# number_source_modified : ['2020-12-28t18:44:03']
# online_format : ['image']
# original_format : ['photo, print, drawing']
# other_control_numbers : ['12963981', 'cha2001000128/PP']
# other_formats : [{'label': 'MARCXML Record', 'link': 'https://lccn.loc.gov/2002700239/marcxml'}, {'label': 'MODS Record', 'link': 'https://lccn.loc.gov/2002700239/mods'}, {'label': 'Dublin Core Record', 'link': 'https://lccn.loc.gov/2002700239/dc'}]
# other_title : []
# partof : [{'count': 2767, 'title': 'fine prints: japanese, pre-1915', 'url': 'https://www.loc.gov/collections/japanese-fine-prints-pre-1915/?fo=json'}, {'count': 988095, 'title': 'prints & photographs online catalog (library of congress)', 'url': 'https://www.loc.gov/search/?fa=partof:prints+%26+photographs+online+catalog+%28library+of+congress%29&fo=json'}, {'count': 1049052, 'title': 'prints and photographs division', 'url': 'https://www.loc.gov/search/?fa=partof:prints+and+photographs+division&fo=json'}, {'count': 1487378, 'title': 'catalog', 'url': 'https://www.loc.gov/search/?fa=partof:catalog&fo=json'}]
# place : [{'latitude': '', 'link': 'https://www.loc.gov/pictures/related/?fi=place&q=Japan--Yokohama-shi&co=jpd', 'longitude': '', 'title': 'Japan--Yokohama-shi'}]
# related : {'neighbors': 'https://www.loc.gov/pictures/related/?&co=jpd&pk=2002700239&st=gallery&sb=call_number#focus'}
# repository : ['Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA']
# reproduction_number : LC-USZC4-8479 (color film copy transparency of 101c, left section)
# LC-USZC4-8480 (color film copy transparency of 101b, center section)
# LC-USZC4-8481 (color film copy transparency of 101a, right section)
# LC-USZ62-23823 (b&w film copy neg. of 101a, right section)
# LC-USZ62-23822 (b&w film copy neg. of 101b, center section)
# LC-USZ62-23821 (b&w film copy neg. of 101c, left section)
# reproductions : []
# resource_links : ['//hdl.loc.gov/loc.pnp/cph.3g08479', '//hdl.loc.gov/loc.pnp/cph.3g08480', '//hdl.loc.gov/loc.pnp/cph.3g08481', '//hdl.loc.gov/loc.pnp/cph.3a24782', '//hdl.loc.gov/loc.pnp/cph.3a24783', '//hdl.loc.gov/loc.pnp/cph.3a24784']
# resources : [{'caption': 'color film transparency of 101c, left section', 'files': 1, 'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g08000/3g08400/3g08479_150px.jpg', 'url': 'https://www.loc.gov/resource/cph.3g08479/'}, {'caption': 'color film transparency of 101b, center section', 'files': 1, 'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g08000/3g08400/3g08480_150px.jpg', 'url': 'https://www.loc.gov/resource/cph.3g08480/'}, {'caption': 'color film transparency of 101a, right section', 'files': 1, 'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g08000/3g08400/3g08481_150px.jpg', 'url': 'https://www.loc.gov/resource/cph.3g08481/'}, {'caption': 'b&w film copy neg. of 101c, left section', 'files': 1, 'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3a20000/3a24000/3a24700/3a24782_150px.jpg', 'url': 'https://www.loc.gov/resource/cph.3a24782/'}, {'caption': 'b&w film copy neg. of 101b, center section', 'files': 1, 'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3a20000/3a24000/3a24700/3a24783_150px.jpg', 'url': 'https://www.loc.gov/resource/cph.3a24783/'}, {'caption': 'b&w film copy neg.of 101a, right section', 'files': 1, 'image': 'https://tile.loc.gov/storage-services/service/pnp/cph/3a20000/3a24000/3a24700/3a24784_150px.jpg', 'url': 'https://www.loc.gov/resource/cph.3a24784/'}]
# rights : ['<p>The Library of Congress does not&nbsp;own rights to material  in its collections. Therefore, it does not license or charge permission fees  for use of such material and cannot grant or deny permission to publish or  otherwise distribute the material. </p>\n<p>Ultimately, it is the researcher\'s obligation to assess copyright or other use restrictions and  obtain permission from third parties when necessary before publishing or  otherwise distributing materials found in the Library\'s collections. </p>\n<p>For information about reproducing,  publishing, and citing material from this collection, as well as access to the  original items, see: <a href="//www.loc.gov/rr/print/res/371_japa.html">Japanese Fine Prints and Drawings, pre-1915 - Rights and Restrictions Information</a> </p>\n \n']
# rights_advisory : No known restrictions on publication.
# rights_information : No known restrictions on publication.
# score : 19.42971
# shard : 00
# shelf_id : FP 2 - Chadbourne, no. 101 a, b, c (D size) [P&P]
# site : ['pictures', 'catalog']
# sort_date : 1860
# source_collection : Chadbourne collection of Japanese prints (Library of Congress)
# source_created : 2001-05-04T00:00:00Z
# source_modified : 2020-12-28T18:44:03Z
# subject : ['courtesans', 'teahouses', 'entertainment', 'color', 'japanese', 'foreign visitors', 'triptychs', 'yokohama-shi', 'japan', 'woodcuts', 'eating & drinking']
# subject_headings : ['Foreign visitors--Japan--Yokohama-shi--1860', 'Entertainment--Japan--Yokohama-shi--1860', 'Courtesans--Japan--Yokohama-shi--1860', 'Eating & drinking--Japan--Yokohama-shi--1860', 'Teahouses--Japan--Yokohama-shi--1860-1870']
# subjects : [{'color': 'https://www.loc.gov/search/?fa=subject:color&fo=json'}, {'courtesans': 'https://www.loc.gov/search/?fa=subject:courtesans&fo=json'}, {'eating & drinking': 'https://www.loc.gov/search/?fa=subject:eating+%26+drinking&fo=json'}, {'entertainment': 'https://www.loc.gov/search/?fa=subject:entertainment&fo=json'}, {'foreign visitors': 'https://www.loc.gov/search/?fa=subject:foreign+visitors&fo=json'}, {'japan': 'https://www.loc.gov/search/?fa=subject:japan&fo=json'}, {'japanese': 'https://www.loc.gov/search/?fa=subject:japanese&fo=json'}, {'teahouses': 'https://www.loc.gov/search/?fa=subject:teahouses&fo=json'}, {'triptychs': 'https://www.loc.gov/search/?fa=subject:triptychs&fo=json'}, {'woodcuts': 'https://www.loc.gov/search/?fa=subject:woodcuts&fo=json'}, {'yokohama-shi': 'https://www.loc.gov/search/?fa=subject:yokohama-shi&fo=json'}]
# summary : Japanese triptych print shows visitors from several nations enjoying a party in the Fan Room of the Gankirō.
# thumb_gallery : https://tile.loc.gov/storage-services/service/pnp/cph/3g00000/3g08000/3g08400/3g08479_150px.jpg
# timestamp : 2022-04-29T03:11:25.183Z
# title : Gokakoku ... gankirō ni oite sakamori no zu
# translated_title : ['Five nations - merrymaking at the Gankirō tea house.']
# type : ['photo, print, drawing']
# unrestricted : True
# url : https://www.loc.gov/item/2002700239/

# %%
item_data['item']['title']
# Out:
# 'Gokakoku ... gankirō ni oite sakamori no zu'

# %%
collection_info_csv = 'collection_items_data-japanese_prints.csv'

headers = ['item_type', 'date_extracted', 'source_file', 'image_url', 'creator', 'date', 'dig_format', 'phys_format', 'language', 'lc_call', 'lc_control', 'link', 'notes', 'rights', 'subject', 'summary', 'title']

# %%
file_count = 0
items_written = 0
error_count = 0

for file in list_of_item_metadata_files:
    file_count += 1
    with open(file, 'r', encoding='utf-8') as data:
        try:
            item = json.load(data)
        except:
            print('error loading',file)
            error_count += 1
            continue

        item_type = 'Item'

        date_extracted = date_string_for_today

        source_file = str(file)

        image_url = item['image_url'][-1]

        try:
            creator = item['item']['creators'][0]['title']
        except:
            creator = 'Anonymous'

        try:
            date = item['item']['date']
        except:
            date = 'Unknown'

        try:
            dig_format = item['item']['format'][0]
        except:
            dig_format = 'Not Found'

        try:
            phys_format = item['item']['formats'][0]['title']
        except:
            phys_format = 'Not Found'

        try:
            language = item['language'][0]
        except:
            language = 'Not Found'

        try:
            lc_call = item['call_number']
        except:
            lc_call = 'Unknown'

        try:
            lc_control = item['item']['control_number']
        except:
            lc_control = 'Unknown'

        try:
            link = item['link']
        except:
            link = 'Not Found'

        try:
            notes = '; '.join(item['notes'])
        except:
            notes = 'None'

        try:
            rights = item['rights_information']
        except:
            rights = 'Unknown'

        try:
            subject = item['item']['subject_headings']
        except:
            subject = 'None'

        try:
            summary = item['summary']
        except:
            summary = 'Not Found'

        title = item['title']

        row_dict = dict()
        row_dict['item_type'] = item_type
        row_dict['date_extracted'] = date_extracted
        row_dict['source_file'] = source_file
        row_dict['image_url'] = image_url
        row_dict['creator'] = creator
        row_dict['date'] = date
        row_dict['dig_format'] = dig_format
        row_dict['phys_format'] = phys_format
        row_dict['language'] = language
        row_dict['lc_call'] = lc_call
        row_dict['lc_control'] = lc_control
        row_dict['link'] = link
        row_dict['notes'] = notes
        row_dict['rights'] = rights
        row_dict['subject'] = subject
        row_dict['summary'] = summary
        row_dict['title'] = title


        with open(collection_info_csv, 'a', encoding='utf-8') as fout:
            writer = csv.DictWriter(fout, fieldnames=headers)
            if items_written == 0:
                writer.writeheader()
            writer.writerow(row_dict)
            items_written += 1
            print(f'adding item {items_written}')

print('\n\n--- LOG ---')
print('wrote',collection_info_csv)
print('with',items_written,'items')
print(error_count,'errors (info not written)')
# Out:
# adding item 1
# adding item 2
# adding item 3
# adding item 4
# adding item 5
# adding item 6
# adding item 7
# adding item 8
# adding item 9
# adding item 10
# adding item 11
# adding item 12
# adding item 13
# adding item 14
# adding item 15
# adding item 16
# adding item 17
# adding item 18
# adding item 19
# adding item 20
# adding item 21
# adding item 22
# adding item 23
# adding item 24
# adding item 25
# adding item 26
# adding item 27
# adding item 28
# adding item 29
#
#
# --- LOG ---
# wrote collection_items_data-japanese_prints.csv
# with 29 items
# 0 errors (info not written)

# %% [markdown]
# ## Omeka API Usage

# %%
def get_credential(json_file, key, sub_key):
   try:
       with open(json_file) as f:
           data = json.load(f)
           return data[key][sub_key]
   except Exception as e:
       print("Error: ", e)

# %%
baseURL = 'http://jajohnst.projectst.si.umich.edu/omekas/api/'

# API Access Variables for Joel
key_identity = get_credential('secrets.json', 'omeka_joel', 'key_identity')
key_credential = get_credential('secrets.json', 'omeka_joel', 'key_credential')

omekas_credentials_joel = {
    'key_identity': key_identity,
    'key_credential': key_credential
}


# API Access Variables for Instructor
instructor_key_identity = get_credential('secrets.json', 'omeka_instructor', 'key_identity')
instructor_key_credential = get_credential('secrets.json', 'omeka_instructor', 'key_credential')

omekas_credentials_instructor = {
    'key_identity': instructor_key_identity,
    'key_credential': instructor_key_credential
}
